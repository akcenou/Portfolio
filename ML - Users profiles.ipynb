# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет еще раз!\
# Проект и презентация приняты, ты молодец!
#
# Рекомендую почитать статью по выбору метода сегментации,  даже по нашим данным можно попробовать разные методы: https://vaael.ru/ru/article/view?id=1596
#
# Жду проект по SQL.
#
# </div>

# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет!\
# Проект принимаю, жду ссылку на презентацию.
# </div>

# %% [markdown]
# # Материалы
#
# https://drive.google.com/file/d/1GdU5jtvFmPUui7ra2OHCSrJ49TJ1pYrN/view?usp=drive_link

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Дмитрий, привет!
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Привет Сергей! Отправляю проект на проверку, презу сделаю после того, когда проект будет зачтен
# </div>

# %% [markdown]
#    # Аналитический проект для интернет-магазина «Пока все ещё тут»

# %% [markdown]
# **Описание проекта**
#
# Интернет-магазин товаров для дома "Пока все еще тут" желает оптимизировать бизнес и повысить выручку с продаж.
#
# Цель проекта: определить профили пользователей и подготовить таргетированные рекомендации дял каждого из сегмента с целью увеличения выручки.
#
# Предстоящий план работ:
# - подготовить данные;
# - произвести первичный анализ информации (EDA), подготовить визуализации;
# - категоризировать товар для удобства анализа;
# - выявить уровень корелляции численых метрик;
# - сегментировать покупателей и подготвоить их портреты;
# - выдвинуть гипотезы;
# - подготовить выводы и рекомендации.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Каждый аналитический проект должен начинаться с введения, которое содержит: название, краткое описание проекта, цели и задачи и т.д., чтобы читатель сразу понял, о чём проект. Добавь пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    Добавил, подумал что декомпозация по сути и была этим введением и не стал ее опять сюда добавлять..
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ✔️ Описание проекта есть.
# </div>

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# #### Проверка общей информации в датафрейме

# %%
# загружаем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
import scipy.stats as st

# %%
# загружаем данные
try:
    df = pd.read_csv('D:\\Praktikum\\ecom_dataset_upd.csv')
except: 
    df = pd.read_csv('https://code.s3.yandex.net/datasets/ecom_dataset_upd.csv')
    
pd.set_option('display.precision',1)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида</b>
#
#   ⚠️ Не используй, пожалуйста, без острой необходимости, эти параметры:
#
# ```
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# ```
# Из-за них проект сьедает очень много памяти и тормозит при открытии\запуске.
# </div>

# %%
# выведем первичную общую информацию
df.info()
print('--'*25)
print(df[['quantity', 'price']].describe())
df.sample()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   int64
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 350.5+ KB
# --------------------------------------------------
#        quantity    price
# count    7474.0   7474.0
# mean        2.4    478.7
# std        14.5    901.6
# min         1.0      9.0
# 25%         1.0     97.0
# 50%         1.0    135.0
# 75%         1.0    439.0
# max      1000.0  14917.0
#             date                           customer_id  order_id  \
# 3073  2019042410  30a28353-6829-44be-8158-68895dad31e7     14683
#
# ...

# %% [markdown]
# **Выводы по первичной информации**

# %% [markdown]
# - датасет без пропусков с 7474 строками;
# - необходимо изменить формат даты;
# - произвести замену е-ё для удобства классификации;
# - поменять регистр на нижний в столбце с продуктами;

# %% [markdown]
# #### Обработка данных

# %% [markdown]
# *формат данных*

# %%
# смена формата даты 
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d%H')
months = df['date'].dt.strftime('%Y-%m').nunique()

date_min = df['date'].min()
date_max = df['date'].max()

print(f'Дата первой первой покупки: {date_min}')
print(f'Дата последней покупки: {date_max}')
print(f'Количество месяцев: {months}')
# Out:
# Дата первой первой покупки: 2018-10-01 00:00:00
# Дата последней покупки: 2020-01-31 15:00:00
# Количество месяцев: 16

# %%
# приведем столбцы к нижнему регистру и заменим ё на е
df['product'] = (df['product']
                 .str.lower()
                 .str.replace('ё', 'е')
                )

# %% [markdown]
# *дубли*

# %%
# проверка на дубли "в круг"
df.duplicated().sum()
# Out:
# 0

# %%
display(df[df.drop('date', axis=1).duplicated()].head(10))
print('Количество неявных дубликатов: ', df.drop('date', axis=1).duplicated().sum())
# Out:
#                    date                           customer_id  order_id  \
# 58  2018-10-02 18:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 59  2018-10-02 19:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 60  2018-10-02 20:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 63  2018-10-03 04:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 94  2018-10-04 13:00:00  32de7df8-8d4f-4c84-a7b9-c41d00dd83ba     68522
# 126 2018-10-07 17:00:00  ce0e0c29-8c8b-4714-84bd-80957224d4cf     68557
# 147 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 148 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 149 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
# 150 2018-10-08 19:00:00  3de09660-90bc-4a28-aaf1-34c8435fe59c     68574
#
#                                                product  quantity   price
# 58   доска гладильная eurogold professional 130х48 ...         1  3299.0
# ...

# %% [markdown]
# Отбросив дату, видим 1864 неявных дубликата.
#
# Уникальные номера заказов повторяются в разное время и даже дни. Возможная причина - оформляемый заказ не оплачивался (не доходили до процесса оплаты), но тем не менее фиксировался в биллинге и попал в отчет. Примем за правду тот факт, что самый поздний дубликат является истинным заказом и удалим все остальные предшествующие.

# %%
df = df.drop_duplicates(subset=['customer_id', 'order_id', 'product', 'quantity', 'price'], keep='last')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5610 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5610 non-null   datetime64[ns]
#  1   customer_id  5610 non-null   object
#  2   order_id     5610 non-null   int64
#  3   product      5610 non-null   object
#  4   quantity     5610 non-null   int64
#  5   price        5610 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 306.8+ KB

# %% [markdown]
# *Разные пользователи в уникальных заказах*

# %%
# проверим на наличие более 1 уникального покупателя на 1 уникальный заказ
orders_customers = df.groupby('order_id')['customer_id'].nunique()
false_orders = orders_customers[orders_customers > 1]
false_orders
# Out:
# order_id
# 14872    2
# 68785    2
# 69283    2
# 69310    2
# 69345    2
# 69410    2
# 69485    3
# 69531    2
# 69833    2
# 70114    2
# 70542    2
# 70631    2
# 70726    2
# 70808    2
# 70903    2
# 70946    2
# 71054    2
# 71226    2
# 71461    2
# 71480    3
# 71542    2
# 71571    2
# 71648    2
# 71663    2
# 72188    2
# 72778    2
# 72790    2
# 72845    4
# 72950    2
# Name: customer_id, dtype: int64

# %%
# исключим такие заказы
false_orders = false_orders.index.tolist()
df = df.query('order_id not in @false_orders')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5544 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5544 non-null   datetime64[ns]
#  1   customer_id  5544 non-null   object
#  2   order_id     5544 non-null   int64
#  3   product      5544 non-null   object
#  4   quantity     5544 non-null   int64
#  5   price        5544 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 303.2+ KB

# %% [markdown]
# *выбросы*

# %%
# проверим исходные распределения числовых параметров
df[['quantity', 'price']].describe()
# Out:
#        quantity    price
# count    5544.0   5544.0
# mean        2.6    530.4
# std        16.5    973.8
# min         1.0      9.0
# 25%         1.0     90.0
# 50%         1.0    150.0
# 75%         1.0    524.0
# max      1000.0  14917.0

# %%
columns = ['quantity', 'price']

for c in columns:
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 2, 1)
    sns.boxplot(x=df[c])
    plt.title('Распределение ' + ('количества' if c == 'quantity' else 'цены'))

    plt.subplot(1, 2, 2)
    sns.histplot(df[c], bins=30, kde=True)
    plt.title('Гистограмма ' + ('количества' if c == 'quantity' else 'цены'))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# - кол-во товара: диапазон от 1 до 1000 штук, при средней 1.7
# - цена: диапазон от 9 у.е. до 5249 у.е, при средней 463.3 у.е.
#
# Фильтровать по цене неправильно, тем самым могут быть удалены дорогие товары из ассортимента
#
# Рассчитаем 99е персентили по кол-ву товара в чеке для более точной фильтрации:

# %%
qunatity_percentil = np.percentile(df['quantity'], [99])
#price_percentil = np.percentile(df['price'], [99])
print('99й персентиль по количеству товара:', qunatity_percentil)
#print('99й персентиль по цене товара:', price_percentil)
# Out:
# 99й персентиль по количеству товара: [25.57]

# %%
# отфильтруем датафрейм по этому значению
df = df.query('quantity <=25.57')

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Обрезать по прайсу не корректно. Мы так просто теряем самые дорогие товары из анализа. Выбросы стоит смотреть по чеку покупки. Нижнюю границу мы вообще не трогам, у заказчика есть дешевые товары и мы их не модем выкинуть.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    исправил
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ⚠️  Товары мы тоже сильно режем, выведи топ-5 по количеству и посмотри.
#
# </div>

# %%
# кол-во заказов на пользователя
#plt.figure(figsize=(20, 5))

#plt.subplot(1, 2, 1)
#sns.boxplot(x=df.groupby('customer_id')['order_id'].nunique())
#plt.title('Распределения количества заказов по пользователям')
#plt.xlabel('Количество заказов')

#plt.subplot(1, 2, 2)
#sns.histplot(df.groupby('customer_id')['order_id'].nunique(), bins=30, kde=True)
#plt.title('Гистограмма распределения количества заказов по пользователям')
#plt.xlabel('Количество заказов')
#plt.show()

# %%
# проверим также агрегированные данные на выбросы
# добавим столбец с выручкой
df['revenue'] = df['quantity'] * df['price']

# средний чек
plt.figure(figsize=(20, 5))

plt.subplot(1, 2, 1)
sns.boxplot(x=df.groupby('customer_id')['revenue'].sum())
plt.title('Распределения среднего чека по пользователям')
plt.xlabel('Средний чек')

plt.subplot(1, 2, 2)
sns.histplot(df.groupby('customer_id')['revenue'].mean(), bins=30, kde=True)
plt.title('Гистограмма распределения среднего чека по пользователям')
plt.xlabel('Средний чек')
plt.show()

# %% [markdown]
# Визуально видны выбросы, рассчитаем также 99й персентиль:

# %%
#orders_percentil = np.percentile(df.groupby('customer_id')['order_id'].nunique(), [99])
avo_percentil = np.percentile(df.groupby('customer_id')['revenue'].mean(), [99])
#print('99й персентиль по количеству заказов по пользователям:', orders_percentil)
print('99й персентиль по среднему чеку по пользователям:', avo_percentil)
# Out:
# 99й персентиль по среднему чеку по пользователям: [6138.34]

# %% [markdown]
# 99% пользователей имеют чек до 6138.34 у.е., исключим остальных:

# %%
#percentile_customers = (df
#                        .groupby('customer_id')['order_id'].nunique()
#                        .reset_index(name='orders')
#                        .query('orders > 3')
#                       )

# %%
percentile_avo = (df
                    .groupby('customer_id')['revenue'].mean()
                    .reset_index(name='avo')
                    .query('avo > 6138.34')
                    )

#customer_list_orders = percentile_customers['customer_id'].tolist()
customer_list_avo = percentile_avo['customer_id'].tolist()

df = df.query('customer_id not in @customer_list_avo')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5459 entries, 0 to 7473
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5459 non-null   datetime64[ns]
#  1   customer_id  5459 non-null   object
#  2   order_id     5459 non-null   int64
#  3   product      5459 non-null   object
#  4   quantity     5459 non-null   int64
#  5   price        5459 non-null   float64
#  6   revenue      5459 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 341.2+ KB

# %% [markdown]
# Проверим покупателей по количуству заказов:

# %%
df.groupby('customer_id')['order_id'].nunique().sort_values(ascending=False).head(10)
# Out:
# customer_id
# c971fb21-d54c-4134-938f-16b62ee86d3b    125
# 4d93d3f6-8b24-403b-a74b-f5173e40d7db     33
# 73d1cd35-5e5f-4629-8cf2-3fda829d4e58     17
# b7b865ab-0735-407f-8d0c-31f74d2806cc      7
# 0184f535-b60a-4914-a982-231e3f615206      5
# bea7a833-2074-42db-bc49-4457abd3c930      4
# e0535076-6270-4df2-8621-cb06264a94fa      4
# 7d0641a6-e043-487d-b356-38895fe7df84      3
# 41117d9d-94f7-4145-a8c9-cb6675ce7674      3
# d02429ab-22e0-4ff2-9465-3082befde444      3
# Name: order_id, dtype: int64

# %%
df['year_month'] = df['date'].dt.strftime('%Y-%m')

to_delete = ['c971fb21-d54c-4134-938f-16b62ee86d3b', '4d93d3f6-8b24-403b-a74b-f5173e40d7db', '73d1cd35-5e5f-4629-8cf2-3fda829d4e58']

df_test = df.query('customer_id in @to_delete')
df_test
# Out:
#                     date                           customer_id  order_id  \
# 9    2018-10-01 09:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
# 12   2018-10-01 13:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68485
# 20   2018-10-02 08:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68490
# 21   2018-10-02 10:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68491
# 42   2018-10-02 11:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68493
# 43   2018-10-02 11:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68493
# 46   2018-10-02 14:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68503
# 47   2018-10-02 14:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68503
# 48   2018-10-02 14:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68503
# 49   2018-10-02 14:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68503
# 50   2018-10-02 15:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68506
# 64   2018-10-03 08:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68511
# ...

# %%
wholesale_customer = (df_test
                      .groupby('year_month')[['order_id', 'revenue']]
                      .agg({'order_id':'nunique', 'revenue':'mean'})
                      .reset_index()
                     )
                         
fig, ax1 = plt.subplots(figsize=(15, 6))

ax1.bar(wholesale_customer['year_month'],
        wholesale_customer['order_id'],
        color='y', alpha=0.6, label='Средняя выручка')
ax1.set_ylabel('Среднее кол-во заказов')
ax1.tick_params(axis='y')
plt.title('Среднее количество заказов и выручка оптового покупателя')

ax2 = ax1.twinx()
ax2.plot(wholesale_customer['year_month'],
         wholesale_customer['revenue'],
         color='g', marker='o', label='Выручка')
ax2.set_ylabel('Выручка', color='g')
ax2.tick_params(axis='y', labelcolor='g')
plt.show()

# %% [markdown]
# Выделяются покупатели с 125, 33 и 17 заказами, которые очевидно не является оптовыми регулярными покупателеми:
# - покупают часто 1 ед товара;
# - все покупки выполнены за 7 месяцев из 16;
# - средник чек максимум 1600 у.е., скорее описывает обычного покупателя, а не оптового.
#
# Скорее таких пользователей можно назвать "запасливыми", которые иногда приобретают дешевый товар "на прозапас" или не себе (например, 3 тазика, 3 рыбочистки). В общей массе покупателей они является выбросами.

# %%
df = df.query('customer_id not in @to_delete')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5258 entries, 0 to 7473
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5258 non-null   datetime64[ns]
#  1   customer_id  5258 non-null   object
#  2   order_id     5258 non-null   int64
#  3   product      5258 non-null   object
#  4   quantity     5258 non-null   int64
#  5   price        5258 non-null   float64
#  6   revenue      5258 non-null   float64
#  7   year_month   5258 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 369.7+ KB

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Не стоит так резать заказы. Мы можем потерять потенциальных оптовиков, это не обрадует заказчика. Лучше посмотреть внимательный на топ-5 или 10 по количеству заказов и по ним принять решение.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    Исправил
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ⚠️ У нас только один покупатель выделяется, у него на порядок больше остальных заказов.
#
# </div>

# %% [markdown]
# **Промежуточные выводы:**

# %% [markdown]
# В рамках подготовки данных:
#  - произвели общую оценку информации: датафрейм содержит 7474 строки с информацией о заказах за период 16 месяцев
#  - изменили формат данных и привели данные к нижнему регистру
#  - явных дубликатов не обнаружено
#  - выявлены неявные дубликаты при игнорировании даты, произвели их удаление в связи с их противоречивой природой возникновения
#  - обработали выбросы по параметрам цены, кол-ву товара в чеке, а также по кол-ву заказов на уникального покупателя
#  - в общей сложности датафрейм очистили от 2216 строк с непригодной информацией

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Выручка и продажи

# %% [markdown]
# построим визуализации по заказам и выручке за весь период:

# %%
sales = df.groupby('year_month')[['quantity', 'revenue']].agg({'quantity':'count', 'revenue':'sum'}).reset_index()
sales.columns = ['date', 'orders', 'revenue']

# %%
# визуализация
fig, ax1 = plt.subplots(figsize=(15, 6))

ax1.bar(sales['date'], sales['revenue'], color='y', alpha=0.6, label='Выручка')
ax1.set_ylabel('Выручка',  color='y')
ax1.tick_params(axis='y', labelcolor='y')

ax2 = ax1.twinx()
ax2.plot(sales['date'], sales['orders'], color='g', marker='o', label='Количество заказов')
ax2.set_ylabel('Количество заказов', color='g')
ax2.tick_params(axis='y', labelcolor='g')

plt.title('Выручка и количество заказов по месяцам')
plt.show()

# %% [markdown]
# Аналогичная визуализация со средними значениями:

# %%
avg_common = (df
       .groupby('year_month')[['quantity', 'customer_id', 'revenue']]
       .agg(
           {'quantity':'count', 
            'customer_id':'nunique', 
            'revenue':'mean'}
       ).reset_index()
      )
avg_common.columns = ['date', 'orders', 'customers', 'avg_revenue']
avg_common['avg_orders'] = avg_common['orders'] / avg_common['customers']

fig, ax1 = plt.subplots(figsize=(15, 6))

ax1.plot(avg_common['date'], avg_common['avg_revenue'], color='y', marker='o', alpha=0.6, label='Средняя выручка')
ax1.set_ylabel('Средняя выручка', color='y')
ax1.tick_params(axis='y', labelcolor='y')

ax2 = ax1.twinx()  
ax2.plot(avg_common['date'], avg_common['avg_orders'], color='g', marker='o', label='Среднее количество заказов')
ax2.set_ylabel('Среднее количество заказов', color='g')
ax2.tick_params(axis='y', labelcolor='g')

plt.title('Средняя выручка и среднее количество заказов по месяцам')
fig.tight_layout() 
plt.show()

# %% [markdown]
# Выручка по месяцам медленно, но стабильно падает.
#
# Количество заказов тоже, за исключением всплеска кол-ва продаж в апреле-мае 2019 года. Возможно, связано это с весенным посевным сезоном или какими-то распродажами.
#
# Вернемся к этому чуть позже

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ Дела у магазина идут все хуже.
#
# </div>

# %% [markdown]
# #### Топ товаров

# %%
# визуализация
plt.figure(figsize=(15,8))
sns.barplot(x='revenue',y='product',
            data=df.groupby('product')['revenue'].sum().reset_index().sort_values(by='revenue', ascending=False).head(10)
           )

plt.title('Топ-10 товаров по выручке')
plt.xlabel('Выручка')
plt.ylabel('Товар')
plt.show()

# %% [markdown]
# В топе разнообразные типы сумок-тележек и гладильных досок, что неудобно воспринимать визуально.
# Проще привести товары к категориям.

# %% [markdown]
# #### Категоризация

# %% [markdown]
# Построим словари с ключевыми словами и придумаем категории:

# %%
product_category = {
    'Посуда': [
        'блюдце','кувшин','тарелка', 'термокружка', 'сковорода', 'вилка', 'миска' , 'нож', 'ложка', 'ножей', 
        'блюдо', 'салатник', 'хлебница', 'емкость', 'кружка', 'тортница', 'форма', 'лоток', 'крышк', 'кружек', 'фужер', 'стакан',
        'мантоварка', 'бокал', 'столовых', 'бульонниц', 'кастрюл', 'набор посуд', 'бидон', 'сахарница', 'соковарка', 'половник',
        
    ],
    'Кухонные приборы': [
        'чайник', 'салфет', 'просеиватель', 'толкушка', 'сито', 'скатерть', 'скалка', 'скребок кондитерск', 
        'отделитель', 'сотейник', 'рыбочистка', 'вкладыши', 'чайный набор', 'измельчитель', 'терка', 'разделочная доска', 
        'соковыжималка', 'овощеварка', 'миксер', 'противень', 'овощечистка', 'кисточка', 'рассекатель пламени', 'ополаскиватель',
        'пресс для', 'термос', 'разделочн', 'электроштопор', 'защитна', 'венчик', 'зажигалка', 'для кексов', 'концентрат', 'орехоколка',
        
    ],
    'Для дома': [
        'щетка', 'тележка', 'сумка', 'сварка', 'бензин', 'урна', 'линейка', 'штангенциркуль', 'термометр', 'фал', 
        'окномойка', 'весы', 'подкладка', 'коврик', 'подставка', 'контейнер', 'шило', 'коробка', 'ящик', 'швабра', 'таз',
        'корыто', 'банка', 'стяжка', 'швабра', 'ведро', 'стремянк', 'перчатки', 'веник', 'насадка', 'петля',
        'крепеж', 'этажерка', 'ерш', 'котел', 'пружина', 'кофр', 'светильник', 'свер', 'шнур', 'лопат', 'сметка', 'угольник', 
        'ковш', 'скребок 44', 'скребок для окон', 'ручка-скоба', 'инструмент', 'фоторамк', 'пылесос', 'фиксатор', 'отжим для ведра',
        'шпагат', 'мешок для строительного', 'завертка', 'решетка', 'совок', 'основание', 'шпингалет', 'ключница', 'ручка мебельная',
        'уголок',
    ],
    'Декор': [
        'композиция', 'искусственн', 'новогоднее дерево', 'полки', 'муляж'
    ],
    'Текстиль и аксессуары': [
        'плед', 'одеяло', 'пакет', 'гладильн', 'сушилка', 'плечики', 'тряпкодержатель', 'крючок', 'вешал', 
        'ковер', 'наматрасник', 'халат', 'чехол', 'рукав', 'корзина', 'простын', 'подуш', 'полотен', 'утюг', 'ролик', 'комод',
        'покрывало', 'ткань', 'наволочка', 'пододеяльник', 'пуф', 'полка для', 'стеллаж', 'белье', 'глажения', 
    ],
    'Ванная':[
        'штанга', 'штор', 'подголовник', 'ванной', 'прищеп', 'карниз', 'сиденье', 'известкового', 
        'мыло', 'паста', 'вантуз', 'дозатор', 'порош', 'чистящ', 'пена', 'держатель', 'пробка', 'фен', 'средство', 'бальзам для',
        'сетка для', 'мыльница', 'кондиционер', 'гель для', 'увлажняющ', 'бак для', 'ванна 70', 'мешок для деликатной', 
        'отбеливатель', 'тряпка', 'кипятильник'
    ],
    'Рассада': ['рассада']
                }

# %%
# напишем функцию и применим ее для создания столбца-категории
def categorize_product(product):
    for category, keywords in product_category.items():
        if any(keyword in product for keyword in keywords):
            return category
    return 'Цветы и прочее'

df['category'] = df['product'].apply(categorize_product)

# %%
df.groupby('category')['order_id'].count()
# Out:
# category
# Ванная                    180
# Декор                     327
# Для дома                  865
# Кухонные приборы          141
# Посуда                    318
# Рассада                   672
# Текстиль и аксессуары     700
# Цветы и прочее           2055
# Name: order_id, dtype: int64

# %% [markdown]
# Итого получили 8 категорий, самая большая с цветами и прочей растительностью
#
# Посмотрим, как распределена выручка по категориям:

# %%
# выручка по категориям
plt.figure(figsize=(15,8))
sns.barplot(x='revenue',y='category',
            data=df.groupby('category')['revenue'].sum().reset_index().sort_values(by='revenue', ascending=False)
           )

plt.title('Выручка по категориям')
plt.xlabel('Выручка')
plt.ylabel('Категория')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ Хорошая разбивка по категориям.
#
# </div>

# %% [markdown]
# Несмотря на то, что цветов в ассортименте магазина представлено более, чем товаров для дома, выручка во столько же раз меньше.
#
# Тут 50/50 : либо цветы не покупают, либо они стоят мало. Посмотрим далее.

# %%
# Выручка и количество заказов по категориям
fig, ax1 = plt.subplots(figsize=(15, 6))

revenue_counter = df.groupby('category')['revenue'].sum().reset_index()
ax1.bar(revenue_counter['category'], revenue_counter['revenue'], color='y', alpha=0.6, label='Выручка')
ax1.set_ylabel('Выручка',  color='y')
ax1.tick_params(axis='y', labelcolor='y')

order_counter = df.groupby('category')['order_id'].nunique().reset_index()
ax2 = ax1.twinx()
ax2.plot(order_counter['category'], order_counter['order_id'], color='g', marker='o', label='Количество заказов')
ax2.set_ylabel('Количество заказов', color='g')
ax2.tick_params(axis='y', labelcolor='g')

plt.title('Выручка и количество заказов по категориям')
plt.show()

# %% [markdown]
# Теперь стало лучше видно причину: цветы покупают хорошо, во всяком случае лучше, чем товары для дома, а вот денег приносит это не так много.
#
# Взглянем на средний чек:

# %%
# Средний чек и количество заказов по категориям
fig, ax1 = plt.subplots(figsize=(17, 6))

aov = df.groupby('category')['revenue'].mean().reset_index()
ax1.bar(aov['category'], aov['revenue'], color='y', alpha=0.6, label='Средний чек')
ax1.set_ylabel('Средний чек',  color='y')
ax1.tick_params(axis='y', labelcolor='y')

ax2 = ax1.twinx()
ax2.plot(order_counter['category'], order_counter['order_id'], color='g', marker='o', label='Количество заказов')
ax2.set_ylabel('Количество заказов', color='g')
ax2.tick_params(axis='y', labelcolor='g')

plt.title('Средний чек и количество заказов по категориям')
plt.show()

# %% [markdown]
# Еще одно подтверждение: средний чек за цветы в 6 раз меньше чек за товар для дома

# %% [markdown]
# #### Сезонность

# %% [markdown]
# Вернемся к скачку среднего количества продаж в мае 2019 года.
#
# Сопоставим продажи по категориям в этом месяце со средними продажами в месяц за оставшийся период:

# %%
# данные за май
df_may = (df
          .query('year_month == "2019-05"')       
          .groupby('category')['order_id'].nunique().reset_index().sort_values(by='category', ascending=False)
         )
# данные без мая
df_without_may = (df.query('year_month != "2019-05"') 
                    .groupby('category')['order_id'].nunique().reset_index().sort_values(by='category', ascending=False)
                 )
df_without_may['order_id'] = df_without_may['order_id'] /(months - 1)

# сводный датасет
df_compare = pd.merge(df_without_may, df_may, on='category', how='inner')
df_compare.columns = ['category', 'avg_orders', 'orders May 2019']
df_compare['diff'] = (df_compare['orders May 2019'] / df_compare['avg_orders'] - 1) * 100
df_compare
# Out:
#                 category  avg_orders  orders May 2019   diff
# 0         Цветы и прочее        53.5               77   44.0
# 1  Текстиль и аксессуары        42.7               22  -48.5
# 2                Рассада         9.7               53  444.5
# 3                 Посуда        17.3               11  -36.5
# 4       Кухонные приборы         9.1                2  -78.1
# 5               Для дома        52.1               30  -42.4
# 6                  Декор        16.0                6  -62.5
# 7                 Ванная        10.7                4  -62.7

# %%
# сравнительная визуализация
fig, axs = plt.subplots(1, 2, figsize=(22, 5), sharey=True)

sns.barplot(x='category', y='avg_orders', data=df_compare, ax=axs[0])
axs[0].set_title('Среднее количество заказов по категориям за весь период кроме мая 2019')
axs[0].set_xlabel('Категория')
axs[0].set_ylabel('Среднее количество заказов')
axs[0].grid(True, alpha=0.6)

sns.barplot(x='category', y='orders May 2019', data=df_compare, ax=axs[1])
axs[1].set_title('Количество заказов по категориям за май 2019')
axs[1].set_xlabel('Категория')
axs[1].set_ylabel('Количество заказов')
axs[1].grid(True,alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# Так как у нас датасет за неполные два года, цикличность сезонности определить нельзя.
#
# Но в рамках нашего датасета видно, что с наступлением весны товары из категорий "Цветы и прочее" и "Рассада" пользуются бОльшим спросом и рост их продаж (44% и 444% соответственно)даже перекрывает отрицательный спрос на другие товары.
#
# Таким образом, можно говорить о сезонности продаж в весенний дачно-посадочный сезон, в данном случае на примере мая 2019 года

# %% [markdown]
#  <div class="alert alert-warning">
#
#   <b>Комментарий тимлида</b>
#
#   ⚠️ Почему мы смотрим только 2019 год, и вообще отдельно только май?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    В мае 2019 у нас резкий рост количества заказов, поэтому я сравнил заказы за май 2019 года со средним кол-вом заказов в остальные месяцы без учета анализируемого месяца
# </div>

# %% [markdown]
# #### Корреляция параметров

# %% [markdown]
# Проверим коррелицию числовых параметров:

# %%
df_corr = (df[['quantity', 'price', 'revenue']])

plt.figure(figsize=(10, 5))
sns.heatmap(df_corr.corr(), annot=True, cbar=False, robust=True)
plt.show()

# %% [markdown]
# В целом все логично:
# - высокая корреляция между ценой товара и выручкой с заказа
# - слабая и слабая обратная корреляция между количеством товара в чеке, выручкой и ценой соответственно.
#
# Иными словами выручка растет с ценой товара, а кол-во товара в чеке почти никак не влиют на цену или выручку

# %% [markdown]
# **Промежуточные выводы:**

# %% [markdown]
# 1. В динамике определено, что выручка и заказы падают: выручка с 250 тыс. у.е в начале периода, до 150 тыс. у.е в конце периода.
#
# Исключение - рост продаж в в весенние месяцы(апрель-май)
# Причина: повышенный сезонный спрос на цветочные товары и рассаду в посадочный период.
#
# 2.  в топ товаров по выручке входят разного рода сумки-тележки и гладильные доски. Для простоты оценки товаров, произведена их категоризация, по итогу которой получили 8 категорий.
#
# Самая прибыльная - "Товары для дома"(средний чек 1250 у.е)
#
# С наибольшим количеством заказов - "Цветы и прочее" (средний чек 250 у.е)
#
# 3. Тепловая карта корреляции показала высокую связь между выручкой и ценой

# %% [markdown]
# ### Профили покупателей

# %% [markdown]
# #### Сегментация

# %% [markdown]
# Подготовим данные для сегментировани методом Kmeans:

# %%
# кол-во заказов на пользователя и среднее кол-во заказов в месяц
pd.set_option('display.float_format', '{:.4f}'.format)

customers_grouped = df.groupby('customer_id')['order_id'].nunique().reset_index()
customers_grouped['avg_purchases_month'] = customers_grouped['order_id'] / months

customers_grouped.rename(columns={'order_id':'total_orders'}, inplace=True)
customers_grouped
# Out:
#                                customer_id  total_orders  avg_purchases_month
# 0     000d6849-084e-4d9f-ac03-37174eaf60c4             1               0.0625
# 1     001cee7f-0b29-4716-b202-0042213ab038             1               0.0625
# 2     00299f34-5385-4d13-9aea-c80b81658e1b             1               0.0625
# 3     002d4d3a-4a59-406b-86ec-c3314357e498             1               0.0625
# 4     003bbd39-0000-41ff-b7f9-2ddaec152037             1               0.0625
# 5     004d24e9-4a6c-4d0e-8727-8391dfd4b43a             1               0.0625
# 6     005ba170-45e8-42de-93f7-192481ae2659             2               0.1250
# 7     00bd74b1-2792-47db-a2f1-680a09ac5026             1               0.0625
# 8     00c0f92a-121a-4883-a78d-2c7b5fe187de             2               0.1250
# 9     00c95d20-923e-4b45-88fc-53b12931d462             1               0.0625
# 10    00cd704a-a65c-4865-b39a-779f1b4f1d1a             2               0.1250
# ...

# %%
# средний чек на пользователя, среднее кол-во товара в чеке на пользователя, средняя цена на пользователя
df_avg_revenue_quantity_price = df.groupby('customer_id').agg({
    'revenue':'mean',
    'quantity':'mean',
    'price':'mean'
}).reset_index()

df_avg_revenue_quantity_price.columns = ['customer_id', 'avg_revenue', 'avg_quantity', 'avg_price']

df_avg_revenue_quantity_price
# Out:
#                                customer_id  avg_revenue  avg_quantity  \
# 0     000d6849-084e-4d9f-ac03-37174eaf60c4     138.7500        1.0000
# 1     001cee7f-0b29-4716-b202-0042213ab038     442.0000        1.0000
# 2     00299f34-5385-4d13-9aea-c80b81658e1b     914.0000        2.0000
# 3     002d4d3a-4a59-406b-86ec-c3314357e498    1649.0000        1.0000
# 4     003bbd39-0000-41ff-b7f9-2ddaec152037    2324.0000        2.0000
# 5     004d24e9-4a6c-4d0e-8727-8391dfd4b43a    1536.0000       12.0000
# 6     005ba170-45e8-42de-93f7-192481ae2659    3928.5000        1.5000
# 7     00bd74b1-2792-47db-a2f1-680a09ac5026     937.0000        1.0000
# 8     00c0f92a-121a-4883-a78d-2c7b5fe187de     160.5000        1.0000
# 9     00c95d20-923e-4b45-88fc-53b12931d462     186.5000        1.0000
# 10    00cd704a-a65c-4865-b39a-779f1b4f1d1a     106.5000        1.0000
# 11    00e59a12-06d5-47fc-9a33-bfc53aca1e9f    1798.0000        2.0000
# ...

# %%
# совместим две таблицы
customers = pd.merge(df_avg_revenue_quantity_price, customers_grouped, on='customer_id',how='inner')
print(customers.info())
print('--'*25)
display(customers.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2343 entries, 0 to 2342
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          2343 non-null   object
#  1   avg_revenue          2343 non-null   float64
#  2   avg_quantity         2343 non-null   float64
#  3   avg_price            2343 non-null   float64
#  4   total_orders         2343 non-null   int64
#  5   avg_purchases_month  2343 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 128.1+ KB
# None
# --------------------------------------------------
#                             customer_id  avg_revenue  avg_quantity  avg_price  \
# 0  000d6849-084e-4d9f-ac03-37174eaf60c4     138.7500        1.0000   138.7500
# 1  001cee7f-0b29-4716-b202-0042213ab038     442.0000        1.0000   442.0000
# 2  00299f34-5385-4d13-9aea-c80b81658e1b     914.0000        2.0000   457.0000
# ...

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ Параметры для сегментации выбрали верно.
#
# </div>

# %%
# обучим и стандартизируем модель
# далее построим дендограмму
X = customers.drop('customer_id', axis=1)

scaler = StandardScaler()

X_st = scaler.fit_transform(X)
linked = linkage(X_st, method = 'ward')

plt.figure(figsize=(15, 10))
plt.title('Кластеризация клиентов')
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# по нашим параметрам, дендограмма предлагает 3 кластера.

# %% [markdown]
#  <div class="alert alert-warning">
#
#   <b>Комментарий тимлида</b>
#
#   ⚠️ После пересмотра обрезки выбросов количество кластеров может поменяться.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    точно, теперь 3 стало
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ✔️ Да, четко выделяются 3 кластера.
#
# </div>

# %%
km = KMeans(n_clusters = 3, random_state=0)
labels = km.fit_predict(X_st)
customers['cluster_km'] = labels

print(customers.groupby('cluster_km')['customer_id'].nunique())
# Out:
# cluster_km
# 0     796
# 1    1334
# 2     213
# Name: customer_id, dtype: int64

# %%
# "подсветим" ключевые значения сегментов
cluster_features = customers.groupby('cluster_km').mean().reset_index()
numeric_columns = cluster_features.drop(columns=['cluster_km']).columns
cluster_features.style.format({i: '{:.3f}' for i in numeric_columns}) \
    .highlight_max(color='yellowgreen', subset=numeric_columns) \
    .highlight_min(color='coral', subset=numeric_columns)
# Out:
# <style  type="text/css" >
# #T_92254_row0_col2,#T_92254_row1_col1,#T_92254_row1_col3,#T_92254_row1_col4,#T_92254_row1_col5{
#             background-color:  coral;
#         }#T_92254_row0_col4,#T_92254_row0_col5,#T_92254_row1_col2,#T_92254_row2_col1,#T_92254_row2_col3{
#             background-color:  yellowgreen;
#         }</style><table id="T_92254_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cluster_km</th>        <th class="col_heading level0 col1" >avg_revenue</th>        <th class="col_heading level0 col2" >avg_quantity</th>        <th class="col_heading level0 col3" >avg_price</th>        <th class="col_heading level0 col4" >total_orders</th>        <th class="col_heading level0 col5" >avg_purchases_month</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_92254_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# Кластер 0 - '*Частый мелкий клиент*': покупает часто в среднем более 2 заказов. Средний чек и цена товара средние 630 у.е и 601 у.е, покупают как правило только 1 ед. товара за заказ.
#
# Кластер 1 - '*Склонный к оттоку*': совершили один единственный заказ. Средний чек и цена товара средние 574 у.е и 392 у.е, покупают как правило более 2 ед. товара за заказ.
#
# Кластер 2 - '*Редкий крупный клиент*': редко производят более 1 заказа, но приобретают дорогой товар с ценой 2773 у.е, общий чек 3221 у.е., в заказе почти всегда более 1 ед. товара

# %%
# переименуем кластеры и добавим их в общий датафрейм
pd.set_option('display.float_format', None)

df_clustered = pd.merge(df, customers[['customer_id','cluster_km']], on='customer_id',how='left')
df_clustered['cluster_km'] = df_clustered['cluster_km'].replace({0:'Частый мелкий клиент', 1:'Склонный к оттоку', 2:'Редкий крупный клиент'})
df_clustered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5258 entries, 0 to 5257
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5258 non-null   datetime64[ns]
#  1   customer_id  5258 non-null   object
#  2   order_id     5258 non-null   int64
#  3   product      5258 non-null   object
#  4   quantity     5258 non-null   int64
#  5   price        5258 non-null   float64
#  6   revenue      5258 non-null   float64
#  7   year_month   5258 non-null   object
#  8   category     5258 non-null   object
#  9   cluster_km   5258 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 451.9+ KB

# %% [markdown]
# #### Описание сегментов

# %% [markdown]
# Взглянем, что покупают разделенные на кластеры покупатели:

# %%
# Количество заказов по категориям для каждого кластера
pivot_orders = df_clustered.pivot_table(index='category', columns='cluster_km', values='order_id', aggfunc='nunique')

colors = plt.cm.Dark2(range(len(pivot_orders.columns)))
pivot_orders.plot(kind='bar', figsize=(15, 6), color=colors)

plt.title('Количество заказов по категориям для каждого кластера')
plt.xlabel('Категория товара')
plt.xticks(rotation=0, fontsize=12)
plt.ylabel('Количество заказов')
plt.legend(title='Кластер')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.show()

# %% [markdown]
# - *Частый мелкий клиент*: приобретает в основном среднемаржинальные товары из категорий "для дома", "текстиль", "посуда". Также покупает низкодоходные "цветы и прочее" и "рассаду".
#
# - *Редкий крупный клиент*: покупает, как правило, более дорогие товары "для дома" и "текстиль"
#
# - *Склонный к оттоку*: единичные низкодоходные покупки, в большинстве связанные с "цветами", "рассадой", "декором", а также товарами "для дома" и "текстилем"

# %%
# Средний чек по категориям для каждого кластера
pivot_avo = df_clustered.pivot_table(index='category', columns='cluster_km', values='revenue', aggfunc='mean')

colors = plt.cm.Dark2(range(len(pivot_avo.columns)))
pivot_avo.plot(kind='bar', figsize=(15, 6), color=colors)

plt.title('Средний чек по категориям для каждого кластера')
plt.xlabel('Категория товара')
plt.xticks(rotation=0, fontsize=12)
plt.ylabel('Средний чек')
plt.legend(title='Кластер')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Средний чек *Редкого крупного клиента* в несколько раз выше других кластеров, кроме категории "рассада", к которой он очевидно безразличен.
#
# Оставшиеся кластеры показывают несущественную разницу в среднем чеке между собой

# %%
# Количество заказов по месяцам для каждого кластера
pivot_season = df_clustered.pivot_table(index='cluster_km', columns='year_month', values='order_id', aggfunc='nunique')

pivot_season.plot(kind='bar', figsize=(15, 5))

plt.title('Количество заказов по месяцам для каждого кластера')
plt.xlabel('Кластер')
plt.xticks(rotation=0, fontsize=12)
plt.ylabel('Количество заказов')
plt.legend(title='Кластер')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.show()

# %% [markdown]
# - *Частый мелкий клиент*: производит покупки в течение всего периода с относительно небольшими подъемами/падениями.
# Больше всего выделается период перед и сразу после Нового года, возможно связано с приобретением подарков.
#
# - *Редкий крупный клиент*: покупает в течение всего периода равномернее всего, без выраженных скачков
#
# - *Склонный к оттоку*: "садоводы" находятся именно в этой кластере, так как скачок приходится на апрель-май

# %%
clusters = ['Частый мелкий клиент', 'Редкий крупный клиент', 'Склонный к оттоку']

for cl in clusters:
    pivot_category = (df_clustered[df_clustered['cluster_km'] == cl]
                      .pivot_table(index='year_month', columns='category', values='order_id', aggfunc='nunique')
                      )
    pivot_category.plot(kind='bar', figsize=(16, 8))
    plt.title(f'Количество заказов по категориям в динамике для кластера "{cl}"')
    plt.xlabel('Месяц')
    plt.xticks(rotation=0, fontsize=12)
    plt.ylabel('Количество заказов')
    plt.legend(title='Категория')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()  
    plt.show()

# %% [markdown]
# - *Частый мелкий клиент*: с ноября 2019 и до января 2020 года повышенный спрос на товары в категории "Цветы и прочее", видимо в качесте подарков;
#
# - *Редкий крупный клиент*: в апреле 2019 покупалось больше обычного из категории "для дома";
#
# - *Склонный к оттоку*: в весенние месяцы март-май покупает чаще обычного товары из категории "Цветы и прочее" и "Рассаду". Кроме этого с ноября 2019 года наблюдается резкое падаение всех продаж во всех категориях;

# %% [markdown]
# **Промежуточные выводы:**

# %% [markdown]
# Произведена сегментация покупателей методом K-means по агрегированным средним параметрам чека, выручки, частоты покупок и кол-ва товара в чеке.
#
# Итого сформированы 3 профиля покупателей:
#
# 1. *Частый мелкий клиент*:
# - совершает покупки часто, в среднем 2 заказа на пользователя, чек средний 643 у.е., товаров в чеке редко когда более 1.
# - приобретает в основном среднемаржинальные товары из категорий "для дома", "текстиль", "посуда". Также покупает низкодоходные "цветы и прочее".
# - производит покупки в течение всего периода с относительно небольшими подъемами/падениями. Больше всего выделяется период перед и сразу после Нового года, возможно связано с приобретением подарков.
#
# 2. *Редкий крупный клиент*:
# - покупают редко, но в среднем более 1 раза. Средний чек и цена товара высокие 3029 у.е и 2301 у.е, покупают как правило несколько товаров в заказе.
# - покупает как правило более дорогие товары "для дома" и "текстиль"
# - покупает в течение всего периода равномернее всего, без выраженных скачков
#
# 3. *Склонный к оттоку*:
# - совершили только одну покупку на среднюю сумму 524 у.е., в которой более 2 ед. товара
# - единичные низко доходыне покупки, в большинстве связанные с "цветами", "рассадой", "декором"а также товарами "для дома"
# - пик покупок приходится на весну, апрель-май 2019

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#
#   ❌ Нам еще важно посмотреть сезонность категорий товара по каждому из получившихся сегментов покупателей.  Это позволит провести более персонализированные рассылки и рекомендации, а также повысить уровень удовлетворенности клиентов.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    добавил визауализации с выводами
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ✔️ Сезонность изучили.
#
# </div>

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# **Гипотеза 1: Сравнение среднего чека в сегментах**
# - Н0 - Средний чек по сегментам клиентов не отличается;
# - Н1 - Средний чек по сегментам клиентов отличается

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ Нулевая и альтернативная гипотезы сформулированы.
#
#
# </div>

# %%
# подготовим выборки по сегментам
cluster0 = customers[customers['cluster_km'] == 0]
cluster1 = customers[customers['cluster_km'] == 1]
cluster2 = customers[customers['cluster_km'] == 2]

# %%
# проверим распределения
cluster0['avg_revenue'].hist(bins=50, alpha=0.8)
plt.title('Распределение выручки в cluster0')
plt.xlabel('Количество')
plt.ylabel('Выручка')
plt.show()

cluster1['avg_revenue'].hist(bins=50, alpha=0.8)
plt.title('Распределение выручки в cluster1')
plt.xlabel('Количество')
plt.ylabel('Выручка')
plt.show()

cluster2['avg_revenue'].hist(bins=50, alpha=0.8)
plt.title('Распределение выручки в cluster2')
plt.xlabel('Количество')
plt.ylabel('Выручка')
plt.show()

# %% [markdown]
# Так как распределения скорее экспоненциальные, воспользуемся методом Манна-Уитни для сравнения двух выборок.
#
# Напишем функцию с циклами, проверяющие все 3 кластера друг с другом

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ Верно! Критерий Манна-Уитни нам тут подойдет!
#
# </div>

# %%
def hypothesis(dataframes, alpha):
    n = len(dataframes)

    for i in range(n):
        for j in range(i + 1, n):
            df_1 = dataframes[i]
            df_2 = dataframes[j]
            results = st.mannwhitneyu(df_1, df_2)
            print(f'Сравнение выборок {i + 1} и {j + 1}:')
            print('p-уровень значимости:', alpha)
            print('p-значение:', results.pvalue)

            if results.pvalue < alpha:
                print('Отвергаем нулевую гипотезу\n')
            else:
                print('Не получилось отвергнуть нулевую гипотезу\n')

# %% [markdown]
# При условии относительно маленьких выборок как в нашем случае, стоит применить alpha = 0.01 и рассчитать для нее скорректированную версию методом Бонферрони для 3 тестов:

# %%
alpha = 0.01
m = 3
alpha_corr = alpha / m
alpha = alpha_corr

print(f'Скорректированная статистическая значимость равна {alpha}')
# Out:
# Скорректированная статистическая значимость равна 0.0033333333333333335

# %%
hypothesis([cluster0['avg_revenue'], cluster1['avg_revenue'], cluster2['avg_revenue']], alpha)
# Out:
# Сравнение выборок 1 и 2:
# p-уровень значимости: 0.0033333333333333335
# p-значение: 4.040971429216237e-05
# Отвергаем нулевую гипотезу
#
# Сравнение выборок 1 и 3:
# p-уровень значимости: 0.0033333333333333335
# p-значение: 6.987164705644619e-110
# Отвергаем нулевую гипотезу
#
# Сравнение выборок 2 и 3:
# p-уровень значимости: 0.0033333333333333335
# p-значение: 9.519728767608383e-118
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌  Обрати внимание, что тут у нас идет множественная проверка гипотез, уровень стат. значимости надо рассчитывать исходя из этого.
#
# Вот тут можно почитать: http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%B5%D0%BD%D0%BD%D0%B0%D1%8F_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D1%80%D0%BA%D0%B0_%D0%B3%D0%B8%D0%BF%D0%BE%D1%82%D0%B5%D0%B7
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    добавил рассчет скорректированной статистической значимости
# </div>
#
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ⚠️ Поправка есть.
#
# Однако Бонферрони используется редко. Эта поправка слишком сильно уменьшает уровень альфа, опровергнуть нулевую гипотезу становится фактически не возможно.
# Лучше использовать не такие сильные поправки (как правило, применяют метод Холма, или метод Шидака).
#
# </div>

# %% [markdown]
# Н0 отвергнута по всем кластерам, присутствиет высокая статистическая значимость в сравнении средних чеков

# %% [markdown]
# **Гипотеза 2: Сравнение частоты покупок в сегментах**
# - Н0 - Частота покупок в сегментах равна;
# - Н1 - Частота покупок в сегментах отличается.

# %%
# проверим распределения
cluster0['avg_quantity'].hist(bins=50, alpha=0.8)
plt.title('Распределение выручки в cluster0')
plt.xlabel('Количество')
plt.ylabel('Выручка')
plt.show()

cluster1['avg_quantity'].hist(bins=50, alpha=0.8)
plt.title('Распределение выручки в cluster1')
plt.xlabel('Количество')
plt.ylabel('Выручка')
plt.show()

cluster2['avg_quantity'].hist(bins=50, alpha=0.8)
plt.title('Распределение выручки в cluster2')
plt.xlabel('Количество')
plt.ylabel('Выручка')
plt.show()

# %% [markdown]
# Используем тот же метод Манна-Уитни:

# %%
hypothesis([cluster0['avg_quantity'], cluster1['avg_quantity'], cluster2['avg_quantity']], alpha)
# Out:
# Сравнение выборок 1 и 2:
# p-уровень значимости: 0.0033333333333333335
# p-значение: 5.592707389265694e-40
# Отвергаем нулевую гипотезу
#
# Сравнение выборок 1 и 3:
# p-уровень значимости: 0.0033333333333333335
# p-значение: 0.07696412548232169
# Не получилось отвергнуть нулевую гипотезу
#
# Сравнение выборок 2 и 3:
# p-уровень значимости: 0.0033333333333333335
# p-значение: 1.988571239512984e-09
# Отвергаем нулевую гипотезу

# %% [markdown]
# Во второй гипотезе не удалось отвергнуть нулевую гипотезу при сравнении выборок 1 и 3, что говорит о недостаточности данных для утверждения, что выборки статистически отличаются

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ✔️ Проверка гипотез подтвердила корректность разбиения на сегменты!
#
# </div>

# %% [markdown]
# ### Итоговые выводы

# %% [markdown]
#   В рамках аналитического проекта для интернет-магазина "Пока все еще тут" сначала были проверены общие данные датасета: 7474 строк с данными о заказах в магазине за 16 месяцев.
#
#   Далее выполнены подготовительные работы по очистке данных от дубликатов и выбросов, датасет приведен в удобный для анализа формат. В общей сложности были удалены 2216 строк информации, что составляет 30% от начального объема. 1846 строк были удалены из-за возможной ошибки в биллинговой системе заказчика или системе отчетности, формирующей выгрузку, так как в нее попадают данные с номером одного и того же заказа за разное время.
#
# Далее высчитаны объемы продаж и выручки по месяцам, наблюдается отрицательная динамика как по выручке (с 250 тыс. у.е в начале периода, до 150 тыс. у.е в конце периода), так и по кол-ву заказов.
#
# Для удобства товары были разделены на 8 категорий, среди которых были выявленая самая прибыльная - "товары для дома" (средний чек 1250 у.е). Чаще всего покупают товары в категории "Цветы и прочее" (средний чек 250 у.е)
#
# Удалось выявить сезонный спрос на товары в категориях "Цветы и прочее" и "Рассада", наблюдающийся в весенние месяцы, а именно апрель-май 2019 года. Возможная причина: дачный сезон и время для посадки растений/овощей.
#
# В конце на основании полученной информации, были подготовлены профили покупателей и проверены гипотезы.
#
# Для подготовки профилей покупателей, была произведена сегментация покупателей по агрегированным средним параметрам чека, выручки, частоты покупок и кол-ва торава в чеке.
#
# Итого сформированы 3 профиля покупателей:
#
# 1. **Частый мелкий клиент**:
# - средний чек - 630 у.е;
# - средняя цена товара - 601 у.е;
# - среднее кол-во заказов - 2;
# - товаров в заказе - 1.2;
# - приоритетные товары: "для дома", "текстиль", "посуда", "цветы и прочее";
# - имеет особо высокий спрос на товары "Цветы и прочее" в предпраздничные месяцы начиная с ноября и заканчивая январем;
#
# 2. **Склонный к оттоку**:
# - средний чек - 574 у.е;
# - средняя цена товара - 392 у.е;
# - среднее кол-во заказов - 1;
# - товаров в заказе - 2.6;
# - приоритетные товары: "для дома", "текстиль", "цветы и прочее"
# - имеет особо высокий спрос на товары "Цветы и прочее" и "Рассаду" в весенние месяцы в марте по май. Кроме прочего продажи в этом кластере с ноября 2019 резко упали.
#
# 3. **Редкий крупный клиент**:
# - средний чек - 3221 у.е;
# - средняя цена товара - 2773 у.е;
# - среднее кол-во заказов - 1.3;
# - товаров в заказе - 1.7;
# - приоритетные товары: "для дома", "текстиль";
# - имеет особо высокий спрос на товары "для дома" апреле месяце перед майскими праздниками;

# %% [markdown]
# **Рекомендации для стимуляции роста выручки в каждой группе покупателей**:

# %% [markdown]
# **1. Частый мелкий клиент**:
#
# Цели: Увеличение среднего чека, стимулирование повторных покупок.
#
# - внедрить систему накопительных скидок или бонусов за каждую покупку.
# - использовать данные о покупках для создания персонализированных предложений.
# - учитывая всплеск покупок перед Новым годом, запустить специальные акции и подарочные наборы.
# - предлагать сопутствующие товары к тем, что клиент уже купил.
#
# **2. Редкий крупный клиент**:
#
# Цели: Увеличение частоты покупок и удержание клиентов.
#
# - подарочные сертификаты, чтобы клиенты могли дарить их своим знакомым и друзьям.
# - создание интересных и информативных рассылок о новых поступлениях и акциях, которые будут интересны именно этой группе клиентов.
#
# **3. Склонный к оттоку**:
#
# Цели: Удержание клиентов и стимулирование повторных покупок.
#
# - провести опросы среди клиентов, чтобы понять, почему они сделали только одну покупку.
# - предлагать скидку на вторую покупку.
# - создать контент, который поможет клиентам лучше узнать о ваших товарах. Например, статьи о том, как ухаживать за растениями или как выбрать декор для дома.
# - запустить специальные предложения на весенний ассортимент, чтобы вернуть клиентов в магазин.

# %% [markdown]
# **Иные предложения**:
#
# 1. Проанализировать биллинговую систему/систему отчетности на корректность алгоритмов выгрузки данных.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Заказчику нужны подробные описание и рекомендации по сегментам. У какого сегмента, на какую среднюю сумму, как часто и с каким средним прайсом покупают. Каким клиентам когда и какие категории товара рассылать в рекламных предложениях. Как и для какого сегмента можно попытаться увеличить количество продаваемого товара, повысить возвращаемость покупателей и т.д. Это же была наша основная цель.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#    дописал итоги
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ⚠️ Стоит объединить описание сегмента и рекомендации, так будет легче воспринимать:
#
# 0 сегмент: описание, предпочтительные категории товара и их сезон, рекомендации
#
# 1 сегмент: и т.д.
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#   <b>Чек-лист доработок</b>
#
#   📃 Добавить описание проекта.
#
#   📃 Пересмотреть обрезку выбросов.
#
#   📃 По каждому сегменту посмотреть предпочтительные категории товара и сезонность.
#
#   📃 Установить уровень стат. значимости опираясь на множественную проверку гипотез.
#
#   📃 В общем выводе, добавить подробные описание и рекомендации для каждого сегмента отдельно.
#
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится.
# </div>
